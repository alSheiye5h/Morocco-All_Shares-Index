# %%
import numpy as np
import pandas as pd
import math
import CasaBourseScrap  as cbs
from CasaBourseScrap.quick import scrape_casablanca_bourse_js_click
from datetime import datetime, timedelta

# %%
stocks = pd.DataFrame(cbs.notation(), columns = ['name'])
stocks
# Out:
#             name
# 0         Addoha
# 1           AFMA
# 2    Afric Indus
# 3   Afriquia Gaz
# 4           Agma
# ..           ...
# 69        Unimer
# 70    Wafa Assur
# 71      Zellidja
# 72          MASI
# 73         MSI20
#
# [74 rows x 1 columns]

# %%
data = scrape_casablanca_bourse_js_click()
data
# Out:
# 🌐 Navigating to Casablanca Bourse website...
# ✅ Page loaded successfully
#
# 📄 SCRAPING PAGE 1...
# 📊 Found 50 rows on page 1
#   ✅ ADH - DOUJA PROM ADDOHA
#   ✅ ADI - ALLIANCES
#   ✅ AFI - AFRIC INDUSTRIES SA
#   ✅ AFM - AFMA
#   ✅ AGM - AGMA
#   ✅ AKT - AKDITAL
#   ✅ ALM - ALUMINIUM DU MAROC
#   ✅ ARD - ARADEI CAPITAL
#   ✅ ATH - AUTO HALL
#   ✅ ATL - ATLANTASANAD
#   ✅ ATW - ATTIJARIWAFA BANK
#   ✅ BAL - BALIMA
#   ✅ BCI - BMCI
#   ✅ BCP - BCP
#   ✅ BOA - BANK OF AFRICA
#   ✅ CDM - CDM
#   ✅ CFG - CFG BANK
#   ✅ CIH - CIH
#   ✅ CMA - CIMENTS DU MAROC
#   ✅ CMG - CMGP GROUP
#   ✅ CMT - MINIERE TOUISSIT
#   ✅ COL - COLORADO
#   ✅ CRS - CARTIER SAADA
#   ✅ CSR - COSUMAR
#   ✅ CTM - CTM
#   ✅ DHO - DELTA HOLDING
#   ✅ DIS - DIAC SALAF
#   ✅ DLM - DELATTRE LEVIVIER MAROC
#   ✅ DRI - DARI COUSPATE
#   ✅ DWY - DISWAY
#   ✅ DYT - DISTY TECHNOLOGIES
#   ✅ EQD - EQDOM
#   ✅ FBR - FENIE BROSSETTE
#   ✅ GAZ - AFRIQUIA GAZ
#   ✅ HPS - HPS
#   ✅ IAM - ITISSALAT AL-MAGHRIB
#   ✅ IBC - IB MAROC.COM
#   ✅ IMO - IMMORENTE INVEST
#   ✅ INV - INVOLYS
#   ✅ JET - JET CONTRACTORS
#   ✅ LBV - LABEL VIE
#   ✅ LES - LESIEUR CRISTAL
#   ✅ LHM - LAFARGEHOLCIM MAROC
#   ✅ M2M - M2M Group
#   ✅ MAB - MAGHREBAIL
#   ✅ MDP - MED PAPER
#   ✅ MIC - MICRODATA
#   ✅ MLE - MAROC LEASING
#   ✅ MNG - MANAGEM
#   ✅ MOX - MAGHREB OXYGENE
# 🎯 Successfully scraped 50 instruments from page 1
#
# 🔄 NAVIGATING TO PAGE 2...
# ✅ Found page 2 button using XPath
# 🖱️ Scrolling to page 2 button...
# 🖱️ Clicking page 2 button using JavaScript...
# ✅ Page 2 button clicked successfully
# ⏳ Waiting for page 2 to load...
# ✅ Successfully navigated to page 2 (active button found)
#
# 📄 SCRAPING PAGE 2...
# 📊 Found 28 rows on page 2
#   ✅ MSA - SODEP-Marsa Maroc
#   ✅ MUT - MUTANDIS SCA
#   ✅ NEJ - AUTO NEJMA
#   ✅ NKL - ENNAKL
#   ✅ OUL - OULMES
#   ✅ PRO - PROMOPHARM S.A.
#   ✅ RDS - RESIDENCES DAR SAADA
#   ✅ REB - REBAB COMPANY
#   ✅ RIS - RISMA
#   ✅ S2M - S.M MONETIQUE
#   ✅ SAH - SANLAM MAROC
#   ✅ SAM - SAMIR
#   ✅ SBM - SOCIETE DES BOISSONS DU MAROC
#   ✅ SID - SONASID
#   ✅ SLF - SALAFIN
#   ✅ SMI - SMI
#   ✅ SNA - STOKVIS NORD AFRIQUE
#   ✅ SNP - SNEP
#   ✅ SOT - SOTHEMA
#   ✅ SRM - REALISATIONS MECANIQUES
#   ✅ STR - STROC INDUSTRIE
#   ✅ TGC - TGCC S.A
#   ✅ TMA - TOTALENERGIES MARKETING MAROC
#   ✅ TQM - TAQA MOROCCO
#   ✅ UMR - UNIMER
#   ✅ VCN - VICENNE
#   ✅ WAA - WAFA ASSURANCE
#   ✅ ZDJ - ZELLIDJA S.A
# 🎯 Successfully scraped 28 instruments from page 2
# ✅ Removed 'Page' column from final data
#
# 📈 DATA ANALYSIS:
#    Total records scraped: 78
#    Unique instruments: 78
#
# 🏢 Distribution by compartment:
#    Principal B: 44 instruments
#    Principal A: 25 instruments
#    Alternatif A: 5 instruments
#    Principal F: 4 instruments
#
# 📑 Distribution by category:
#    Actions 1ère Ligne: 78 instruments
#
# 🔚 Closing browser...
#    Ticker     Code_ISIN                               Emetteur  \
# 0     ADH  MA0000011512       DOUJA PROMOTION GROUPE ADDOHA SA
# 1     ADI  MA0000011819  ALLIANCES DEVELOPPEMENT IMMOBILIER SA
# 2     AFI  MA0000012114                    AFRIC INDUSTRIES SA
# 3     AFM  MA0000012296                                AFMA SA
# 4     AGM  MA0000010944                                   AGMA
# ..    ...           ...                                    ...
# 73    TQM  MA0000012205                           TAQA MOROCCO
# 74    UMR  MA0000012023                                 UNIMER
# 75    VCN  MA0000012759                                VICENNE
# 76    WAA  MA0000010928                         WAFA ASSURANCE
# 77    ZDJ  MA0000010571                           ZELLIDJA S.A
#
#              Instrument           Categorie  Compartiment Nombre_titres
# 0     DOUJA PROM ADDOHA  Actions 1ère Ligne   Principal A   402 551 254
# 1             ALLIANCES  Actions 1ère Ligne   Principal A    22 078 588
# 2   AFRIC INDUSTRIES SA  Actions 1ère Ligne   Principal B       291 500
# 3                  AFMA  Actions 1ère Ligne   Principal B     1 000 000
# 4                  AGMA  Actions 1ère Ligne  Alternatif A       200 000
# ..                  ...                 ...           ...           ...
# 73         TAQA MOROCCO  Actions 1ère Ligne   Principal A    23 588 542
# 74               UNIMER  Actions 1ère Ligne   Principal B    11 413 880
# 75              VICENNE  Actions 1ère Ligne   Principal F    10 258 850
# 76       WAFA ASSURANCE  Actions 1ère Ligne   Principal A     3 500 000
# 77         ZELLIDJA S.A  Actions 1ère Ligne   Principal B       572 849
#
# [78 rows x 7 columns]

# %%
try:
    # Get only the most recent day (latest price)
    end_date = datetime.today().date()
    start_date = end_date - timedelta(days=1)  # Just get yesterday and today
    
    print(f"Fetching latest price data: {start_date} to {end_date}")
    
    data = cbs.load_data('CIH', start=start_date.isoformat(), end=end_date.isoformat(), method="cloudscraper")
    
    if data is not None and hasattr(data, 'shape') and data.shape[0] > 0:
        print("✅ Success! Data shape:", data.shape)
        
    else:
        print("❌ No data retrieved or empty dataset")
        
except Exception as e:
    print(f"Error: {e}")

data
